# %%
print('Hello World')
# Out:
# Hello World

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\andre\Documents\JupyterNotebooks\Introduction

# %%
import matplotlib.pyplot as plt
data = [1, 2, 3, 4, 5]
plt.plot(data)
plt.ylabel('My data')
plt.show()
